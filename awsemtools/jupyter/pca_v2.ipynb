# %%
import awsemtools as awt
import matplotlib.pyplot as plt

# %%
trajectory=awt.Trajectory(pdb_file='awsemtools/tests/data/p65p50.pdb',dcd_file='awsemtools/tests/data/p65p50.dcd')
trajectory.set_selection(selection = 'name CA')
trajectory.set_frames(stride = 5)
pca=awt.PCA.fit_coordinates(trajectory)
pca.plot_projection(5)
# Out:
# @> 3073 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> DCD file contains 1000 coordinate sets for 3073 atoms.
# @> DCD file was parsed in 0.01 seconds.
# @> 35.24 MB parsed at input rate 2538.97 MB/s.
# @> 1000 coordinate sets parsed at input rate 72039 frame/s.

# %%
#awt.PCA.fit(trajectory.coords.)

# %%
#pca=awt.PCA.fit_coordinates(trajectory)
#plt.plot(pca.eigenvalues)

# %%
pca.plot_projection(5)

# import seaborn as sns
# import pandas as pd
# data=pd.DataFrame(test)
# data.index.name='frames'
# data.columns.name='PC'
# data=data.reset_index()
# data=data.melt(id_vars='frames')
# data['PC']+=1
# sns.relplot(data[data['PC']<5],x='frames',y='value',row='PC',kind="line",height=1,aspect=10, hue='PC', palette="crest")
# # sns.pairplot(data.iloc[:,:5])
#plt.plot(test[:,:5])

# %%
# Don't call outside software.
# Interplatform

import awsemtools as awt

pca = awt.PCA('awsemtools/tests/data/p65p50.pdb','awsemtools/tests/data/p65p50.dcd')
pca.fit()

pca.animate() # widget if possible.
pca.project() #

qvalue = awt.q_value('awsemtools/tests/data/p65p50.pdb','awsemtools/tests/data/p65p50.dcd', type='wolynes')

q_value.monomer() #multiple values
q_value.interface() #multiple interfaces
q_relative('awsemtools/tests/data/p65p50.pdb')
q_value.globalq()

parse_energy_file('energy.log')

#Wrap mdtraj
awt.rmsd()
awt.rg()
awt.contact_map()

#TODO pyemma
awt.free_energy_analysis(pdb, dcd, reaction_coordinate, reaction_coordinate2) #WHAM, pyemma?
awt.clustering() #hierarchical
awt.MSM = pyemma.msm.MSM #Markov state models.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [6], line 6
#       1 # Don't call outside software.
#       2 # Interplatform
#       4 import awsemtools as awt
# ----> 6 pca = awt.PCA('awsemtools/tests/data/p65p50.pdb','awsemtools/tests/data/p65p50.dcd')
#       7 pca.fit()
#       9 pca.animate() # widget if possible.
#
# TypeError: __init__() takes 2 positional arguments but 3 were given

# %%
import pyemma

# %%
pca.score(features)
# Out:
# -6341.7783

# %%
import awsemtools
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [61], line 1
# ----> 1 awt.MSM = pyemma.msm.MSM
#
# NameError: name 'awt' is not defined

# %%
git clone https://github.com/cabb99/awsemtools.git
cd awsemtools
pip install -e .

# %%
pip install awsemtools
conda install awsemtools
