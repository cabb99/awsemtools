# %%
import awsemtools as awt

# %%
trajectory=awt.Trajectory(pdb_file='awsemtools/tests/data/p65p50.pdb',dcd_file='awsemtools/tests/data/p65p50.dcd')
view = trajectory.show_trajectory(smooth=10)
view
# Out:
# @> 3073 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> DCD file contains 1000 coordinate sets for 3073 atoms.
# @> DCD file was parsed in 0.02 seconds.
# @> 35.24 MB parsed at input rate 2208.50 MB/s.
# @> 1000 coordinate sets parsed at input rate 62663 frame/s.
# NGLWidget(max_frame=999)
# Info) VMD for LINUXAMD64, version 1.9.4a55 (October 19, 2021)
# Info) Exiting normally.
# OpenGLDisplayDevice) Destroying OptiX RTRT context...
# OpenGLDisplayDevice) OptiX RTRT context destroyed.

# %%
from scipy.spatial import distance as sdist
import numpy as np
import pandas as pd

trajectory.set_selection('name CA')

ij = np.argwhere(sdist.squareform(sdist.pdist(trajectory.reference.getCoords()))<9.5)
ij = ij[ij[:,1] - ij[:,0]>3]
i,j=ij.T
distance = [sdist.squareform(sdist.pdist(c))[i,j] for c in trajectory.coords]
# Out:
#          0         1         2         3         4         5         6     \
# 0    7.489429  6.230007  5.030931  7.095989  7.331422  8.307017  8.223944
# 1    7.445483  6.446707  5.081118  6.844536  7.481192  8.417966  8.214682
# 2    8.087740  6.884092  5.369577  7.251237  7.324037  8.260537  8.109852
# 3    7.656452  6.688835  5.163962  6.699462  7.378590  8.317729  8.291695
# 4    7.834181  6.612826  5.309672  7.143604  7.441027  8.733794  8.539796
# ..        ...       ...       ...       ...       ...       ...       ...
# 995  7.339762  6.264132  5.283557  6.959947  7.498126  8.626296  8.492956
# 996  8.471768  7.179560  6.295131  8.310095  7.931585  9.090450  8.738112
# 997  8.561266  6.813386  5.521906  8.125145  8.404997  9.409121  8.864395
# 998  7.051233  6.215392  5.222224  6.944179  7.019353  8.188925  8.483308
# 999  7.254902  6.100927  4.993323  7.166793  7.354161  8.197696  8.121245
#
#          7         8         9     ...      2908      2909      2910  \
# ...

# %%
trajectory.vmd()
# Out:
# Info) VMD for LINUXAMD64, version 1.9.4a55 (October 19, 2021)
# Info) http://www.ks.uiuc.edu/Research/vmd/
# Info) Email questions and bug reports to vmd@ks.uiuc.edu
# Info) Please include this reference in published work using VMD:
# Info)    Humphrey, W., Dalke, A. and Schulten, K., `VMD - Visual
# Info)    Molecular Dynamics', J. Molec. Graphics 1996, 14.1, 33-38.
# Info) -------------------------------------------------------------
# Info) Multithreading available, 12 CPUs, ISA dispatch enabled.
# Info)   CPU features: SSE2 SSE4.1 AVX AVX2 FMA F16 HT
# Info) Free system memory: 111GB (88%)
# Info) Creating CUDA device pool and initializing hardware...
# Info) Detected 1 available CUDA accelerator::
# Info) [0] NVIDIA GeForce RTX 3080 Ti 80 SM_8.6 1.7 GHz, 12GB RAM SP32 KT AE2 ZC
# Info) OpenGL renderer: NVIDIA GeForce RTX 3080 Ti/PCIe/SSE2
# Info)   Features: STENCIL MSAA(4) MDE CVA MTX NPOT PP PS GLSL(OVFGS)
# Info)   Full GLSL rendering mode is available.
# ...
